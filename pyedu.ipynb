# %%
# Out:
# 4

# %%
import pydot

def create_concept_map(title, nodes, edges):
    graph = pydot.Dot(graph_type='digraph', label=title, fontsize="20", color="red", fontcolor="black", style="filled", fillcolor="white")
    for node in nodes:
        graph.add_node(pydot.Node(node[0], label=node[1]))
    for edge in edges:
        graph.add_edge(pydot.Edge(edge[0], edge[1], label=edge[2] if len(edge) > 2 else ""))
    return graph

# Data Collection and Management
nodes_dc = [("RQ", "Research Questions"), ("DS", "Data Sources"), ("DCT", "Data Collection Tools"), 
            ("P", "pandas"), ("O", "openpyxl"), ("R", "requests")]
edges_dc = [("RQ", "DS", "leads to"), ("DS", "DCT", "uses"), 
            ("DCT", "P", "includes"), ("DCT", "O", "includes"), ("DCT", "R", "includes")]
concept_map_dc = create_concept_map("Data Collection and Management", nodes_dc, edges_dc)
concept_map_dc.write_png('data_collection_and_management.png')

# %%
# from graphviz import Digraph

# def create_concept_map(title, nodes, edges):
#     dot = Digraph(comment=title)
#     for node in nodes:
#         dot.node(node[0], node[1])
#     for edge in edges:
#         dot.edge(edge[0], edge[1], edge[2] if len(edge) > 2 else "")
#     return dot

# # Data Collection and Management
# nodes_dc = [("RQ", "Research Questions"), ("DS", "Data Sources"), ("DCT", "Data Collection Tools"), 
#             ("P", "pandas"), ("O", "openpyxl"), ("R", "requests")]
# edges_dc = [("RQ", "DS", "leads to"), ("DS", "DCT", "uses"), 
#             ("DCT", "P", "includes"), ("DCT", "O", "includes"), ("DCT", "R", "includes")]
# concept_map_dc = create_concept_map("Data Collection and Management", nodes_dc, edges_dc)

# # Data Cleaning and Preprocessing
# nodes_dcp = [("RD", "Raw Data"), ("DCS", "Data Cleaning Steps"), ("P", "pandas"), ("N", "numpy")]
# edges_dcp = [("RD", "DCS", "goes through"), ("DCS", "P", "uses"), ("DCS", "N", "uses")]
# concept_map_dcp = create_concept_map("Data Cleaning and Preprocessing", nodes_dcp, edges_dcp)

# # Data Analysis and Visualization
# nodes_dav = [("AG", "Analysis Goals"), ("DAT", "Data Analysis Tools"), ("P", "pandas"), 
#              ("VT", "Visualization Tools"), ("M", "matplotlib"), ("S", "seaborn")]
# edges_dav = [("AG", "DAT", "requires"), ("DAT", "P", "uses"), ("AG", "VT", "requires"), 
#              ("VT", "M", "uses"), ("VT", "S", "uses")]
# concept_map_dav = create_concept_map("Data Analysis and Visualization", nodes_dav, edges_dav)

# # Advanced Data Analysis
# nodes_ada = [("ARQ", "Advanced Research Questions"), ("MLT", "Machine Learning Tools"), 
#              ("SK", "scikit-learn"), ("NLPT", "NLP Tools"), ("N", "nltk"), ("SP", "spaCy")]
# edges_ada = [("ARQ", "MLT", "requires"), ("MLT", "SK", "includes"), 
#              ("ARQ", "NLPT", "requires"), ("NLPT", "N", "includes"), ("NLPT", "SP", "includes")]
# concept_map_ada = create_concept_map("Advanced Data Analysis", nodes_ada, edges_ada)

# # Sharing and Collaborating
# nodes_sc = [("PS", "Project Sharing"), ("CT", "Collaboration Tools"), 
#             ("JN", "Jupyter Notebooks"), ("GC", "Google Colab"), ("G", "GitHub")]
# edges_sc = [("PS", "CT", "requires"), ("CT", "JN", "includes"), ("CT", "GC", "includes"), ("CT", "G", "includes")]
# concept_map_sc = create_concept_map("Sharing and Collaborating", nodes_sc, edges_sc)

# # Render the concept maps
# concept_map_dc.render(filename='data_collection_and_management', format='png', cleanup=True)
# concept_map_dcp.render(filename='data_cleaning_and_preprocessing', format='png', cleanup=True)
# concept_map_dav.render(filename='data_analysis_and_visualization', format='png', cleanup=True)
# concept_map_ada.render(filename='advanced_data_analysis', format='png', cleanup=True)
# concept_map_sc.render(filename='sharing_and_collaborating', format='png', cleanup=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from graphviz import Digraph
#       3 def create_concept_map(title, nodes, edges):
#       4     dot = Digraph(comment=title)
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
import pydot

def create_concept_map(title, nodes, edges):
    graph = pydot.Dot(graph_type='digraph', label=title, fontsize="20", fontcolor="black", style="filled", fillcolor="lightgrey", splines="true")
    for node in nodes:
        graph.add_node(pydot.Node(node[0], label=node[1], shape="box", style="rounded, filled", fillcolor="lightblue", fontsize="12", fontcolor="black"))
    for edge in edges:
        graph.add_edge(pydot.Edge(edge[0], edge[1], label=edge[2] if len(edge) > 2 else "", fontsize="10", fontcolor="blue", color="black"))
    return graph

# Data Collection and Management
nodes_dc = [("RQ", "Research Questions"), ("DS", "Data Sources"), ("DCT", "Data Collection Tools"), 
            ("P", "pandas"), ("O", "openpyxl"), ("R", "requests")]
edges_dc = [("RQ", "DS", "leads to"), ("DS", "DCT", "uses"), 
            ("DCT", "P", "includes"), ("DCT", "O", "includes"), ("DCT", "R", "includes")]
concept_map_dc = create_concept_map("Data Collection and Management", nodes_dc, edges_dc)
concept_map_dc.write_png('data_collection_and_management.png')

# Data Cleaning and Preprocessing
nodes_dcp = [("RD", "Raw Data"), ("DCS", "Data Cleaning Steps"), ("P", "pandas"), ("N", "numpy")]
edges_dcp = [("RD", "DCS", "goes through"), ("DCS", "P", "uses"), ("DCS", "N", "uses")]
concept_map_dcp = create_concept_map("Data Cleaning and Preprocessing", nodes_dcp, edges_dcp)
concept_map_dcp.write_png('data_cleaning_and_preprocessing.png')

# Data Analysis and Visualization
nodes_dav = [("AG", "Analysis Goals"), ("DAT", "Data Analysis Tools"), ("P", "pandas"), 
             ("VT", "Visualization Tools"), ("M", "matplotlib"), ("S", "seaborn")]
edges_dav = [("AG", "DAT", "requires"), ("DAT", "P", "uses"), ("AG", "VT", "requires"), 
             ("VT", "M", "uses"), ("VT", "S", "uses")]
concept_map_dav = create_concept_map("Data Analysis and Visualization", nodes_dav, edges_dav)
concept_map_dav.write_png('data_analysis_and_visualization.png')

# Advanced Data Analysis
nodes_ada = [("ARQ", "Advanced Research Questions"), ("MLT", "Machine Learning Tools"), 
             ("SK", "scikit-learn"), ("NLPT", "NLP Tools"), ("N", "nltk"), ("SP", "spaCy")]
edges_ada = [("ARQ", "MLT", "requires"), ("MLT", "SK", "includes"), 
             ("ARQ", "NLPT", "requires"), ("NLPT", "N", "includes"), ("NLPT", "SP", "includes")]
concept_map_ada = create_concept_map("Advanced Data Analysis", nodes_ada, edges_ada)
concept_map_ada.write_png('advanced_data_analysis.png')

# Sharing and Collaborating
nodes_sc = [("PS", "Project Sharing"), ("CT", "Collaboration Tools"), 
            ("JN", "Jupyter Notebooks"), ("GC", "Google Colab"), ("G", "GitHub")]
edges_sc = [("PS", "CT", "requires"), ("CT", "JN", "includes"), ("CT", "GC", "includes"), ("CT", "G", "includes")]
concept_map_sc = create_concept_map("Sharing and Collaborating", nodes_sc, edges_sc)
concept_map_sc.write_png('sharing_and_collaborating.png')

# %%
import pydot

def create_concept_map(title, nodes, edges):
    graph = pydot.Dot(graph_type='digraph', label=title, fontsize="20", fontcolor="black", style="filled", fillcolor="lightgrey", splines="true")
    for node in nodes:
        graph.add_node(pydot.Node(node[0], label=node[1], shape="box", style="rounded, filled", fillcolor="lightblue", fontsize="12", fontcolor="black"))
    for edge in edges:
        graph.add_edge(pydot.Edge(edge[0], edge[1], label=edge[2] if len(edge) > 2 else "", fontsize="10", fontcolor="blue", color="black"))
    return graph

# Nodes for Python Syntax and Core Principles concept map
nodes_ps = [("PS", "Python Syntax and Core Principles"), 
            ("I", "Indentation"), 
            ("C", "Comments"), 
            ("IL", "Importing Libraries")]

# Edges for Python Syntax and Core Principles concept map
edges_ps = [("PS", "I", "defines code blocks"),
            ("PS", "C", "denoted by #"),
            ("PS", "IL", "uses import statement")]

# Create the concept map
concept_map_ps = create_concept_map("Python Syntax and Core Principles", nodes_ps, edges_ps)

# Render the concept map to a PNG file
concept_map_ps.write_png('python_syntax_and_core_principles.png')

# %%
import pydot

def create_concept_map(title, nodes, edges):
    graph = pydot.Dot(graph_type='digraph', label=title, fontsize="20", fontcolor="black", style="filled", fillcolor="lightgrey", splines="true")
    for node in nodes:
        graph.add_node(pydot.Node(node[0], label=node[1], shape="box", style="rounded, filled", fillcolor="lightblue", fontsize="12", fontcolor="black"))
    for edge in edges:
        graph.add_edge(pydot.Edge(edge[0], edge[1], label=edge[2] if len(edge) > 2 else "", fontsize="10", fontcolor="blue", color="black"))
    return graph

# Nodes for Basic Programming Concepts Relevant to Educational Research
nodes_bp = [("BP", "Basic Programming Concepts"),
            ("VDT", "Variables and Data Types"), 
            ("CS", "Control Structures"), 
            ("F", "Functions"),
            ("LD", "Lists and Dictionaries"),
            ("LM", "Libraries and Modules")]

# Edges for Basic Programming Concepts Relevant to Educational Research
edges_bp = [("BP", "VDT", "store data"),
            ("BP", "CS", "control flow"),
            ("BP", "F", "reuse code"),
            ("BP", "LD", "manage collections"),
            ("BP", "LM", "augment power")]

# Create the concept map
concept_map_bp = create_concept_map("Basic Programming Concepts Relevant to Educational Research", nodes_bp, edges_bp)

# Render the concept map to a PNG file
concept_map_bp.write_png('basic_programming_concepts.png')

# %%
import pydot

def create_concept_map(title, nodes, edges):
    graph = pydot.Dot(graph_type='digraph', label=title, fontsize="20", fontcolor="black", style="filled", fillcolor="lightgrey", splines="true")
    for node in nodes:
        graph.add_node(pydot.Node(node[0], label=node[1], shape="box", style="rounded, filled", fillcolor="lightblue", fontsize="12", fontcolor="black"))
    for edge in edges:
        graph.add_edge(pydot.Edge(edge[0], edge[1], label=edge[2] if len(edge) > 2 else "", fontsize="10", fontcolor="blue", color="black"))
    return graph

# Nodes for Basic Programming Concepts Relevant to Educational Research with Examples
nodes_bp = [("BP", "Basic Programming Concepts"),
            ("VDT", "Variables and Data Types\nExamples: int x = 5, float y = 3.14, str z = 'hello'"), 
            ("CS", "Control Structures\nExamples: for, while, if, elif, else"), 
            ("F", "Functions\nExamples: def my_function(): pass"),
            ("LD", "Lists and Dictionaries\nExamples: list = [1, 2, 3], dict = {'key': 'value'}"),
            ("LM", "Libraries and Modules\nExamples: import pandas as pd, import matplotlib.pyplot as plt")]

# Edges for Basic Programming Concepts Relevant to Educational Research
edges_bp = [("BP", "VDT", "store data"),
            ("BP", "CS", "control flow"),
            ("BP", "F", "reuse code"),
            ("BP", "LD", "manage collections"),
            ("BP", "LM", "augment power")]

# Create the concept map
concept_map_bp = create_concept_map("Basic Programming Concepts Relevant to Educational Research", nodes_bp, edges_bp)

# Render the concept map to a PNG file
concept_map_bp.write_png('basic_programming_concepts_with_examples.png')

# %%
import pydot

def create_concept_map(title, nodes, edges):
    graph = pydot.Dot(graph_type='digraph', label=title, fontsize="20", fontcolor="black", style="filled", fillcolor="lightgrey", splines="true")
    for node in nodes:
        graph.add_node(pydot.Node(node[0], label=node[1], shape="box", style="rounded, filled", fillcolor="lightblue", fontsize="12", fontcolor="black"))
    for edge in edges:
        graph.add_edge(pydot.Edge(edge[0], edge[1], label=edge[2] if len(edge) > 2 else "", fontsize="10", fontcolor="blue", color="black"))
    return graph

# Conceptual map for Text Analysis with OpenAI's GPT API
nodes_text_analysis = [
    ("RQ", "Research Question"),
    ("RQ1", "How can text analysis improve understanding of student feedback?"),
    ("AO", "Analysis Objective"),
    ("AO1", "Analyze and Summarize Feedback"),
    ("APIT", "API Tool"),
    ("APIT1", "OpenAI GPT API")
]

edges_text_analysis = [
    ("RQ", "RQ1", ""),
    ("AO", "AO1", ""),
    ("APIT", "APIT1", ""),
    ("RQ1", "AO1", "Analyze and Summarize Feedback"),
    ("AO1", "APIT1", "OpenAI GPT API")
]

concept_map_text_analysis = create_concept_map("Text Analysis with OpenAI's GPT API", nodes_text_analysis, edges_text_analysis)
concept_map_text_analysis.write_png('text_analysis_with_openai_gpt_api.png')

# Conceptual map for Image Analysis with Google Cloud Vision API
nodes_image_analysis = [
    ("RQ", "Research Question"),
    ("RQ2", "How can image analysis be used to evaluate classroom engagement?"),
    ("AO", "Analysis Objective"),
    ("AO2", "Detect Faces and Analyze Expressions"),
    ("APIT", "API Tool"),
    ("APIT2", "Google Cloud Vision API")
]

edges_image_analysis = [
    ("RQ", "RQ2", ""),
    ("AO", "AO2", ""),
    ("APIT", "APIT2", ""),
    ("RQ2", "AO2", "Detect Faces and Analyze Expressions"),
    ("AO2", "APIT2", "Google Cloud Vision API")
]

concept_map_image_analysis = create_concept_map("Image Analysis with Google Cloud Vision API", nodes_image_analysis, edges_image_analysis)
concept_map_image_analysis.write_png('image_analysis_with_google_cloud_vision_api.png')

print("Conceptual maps generated successfully.")
# Out:
# Conceptual maps generated successfully.

# %%
import pydot

def create_concept_map(title, nodes, edges):
    graph = pydot.Dot(graph_type='digraph', label=title, fontsize="20", fontcolor="black", style="filled", fillcolor="lightgrey", splines="true")
    for node in nodes:
        graph.add_node(pydot.Node(node[0], label=node[1], shape="box", style="rounded, filled", fillcolor="lightblue", fontsize="12", fontcolor="black"))
    for edge in edges:
        graph.add_edge(pydot.Edge(edge[0], edge[1], label=edge[2] if len(edge) > 2 else "", fontsize="10", fontcolor="blue", color="black"))
    return graph

# Nodes for the decision conceptual map
nodes_decision = [
    ("RQ1", "How do test scores vary across classes?"),
    ("DP1", "Is the analysis basic statistics or advanced modeling?"),
    ("BS1", "Basic Script"),
    ("AS1", "Advanced Script"),
    ("BS1_1", "Data Cleaning"),
    ("BS1_2", "Basic Statistics"),
    ("AS1_1", "Statistical Modeling"),
    ("AS1_2", "Machine Learning"),
    
    ("RQ2", "How can text analysis improve understanding of student feedback?"),
    ("DP2", "Is the analysis simple text processing or advanced NLP?"),
    ("BS2", "Basic Script"),
    ("AS2", "Advanced Script"),
    ("BS2_1", "Text Cleaning"),
    ("BS2_2", "Basic Sentiment Analysis"),
    ("AS2_1", "NLP with NLTK"),
    ("AS2_2", "Advanced NLP with OpenAI GPT")
]

# Edges for the decision conceptual map
edges_decision = [
    ("RQ1", "DP1", ""),
    ("DP1", "BS1", "Basic"),
    ("DP1", "AS1", "Advanced"),
    ("BS1", "BS1_1", ""),
    ("BS1", "BS1_2", ""),
    ("AS1", "AS1_1", ""),
    ("AS1", "AS1_2", ""),
    
    ("RQ2", "DP2", ""),
    ("DP2", "BS2", "Simple"),
    ("DP2", "AS2", "Complex"),
    ("BS2", "BS2_1", ""),
    ("BS2", "BS2_2", ""),
    ("AS2", "AS2_1", ""),
    ("AS2", "AS2_2", "")
]

# Create and save the conceptual map
concept_map_decision = create_concept_map("Decision Tree: Basic vs. Advanced Scripts for Educational Research", nodes_decision, edges_decision)
concept_map_decision.write_png('decision_tree_basic_vs_advanced_scripts.png')

print("Decision conceptual map generated successfully.")
# Out:
# Decision conceptual map generated successfully.

# %%
import pydot

def create_concept_map(title, nodes, edges):
    graph = pydot.Dot(graph_type='digraph', label=title, fontsize="20", fontcolor="black", style="filled", fillcolor="lightgrey", splines="true")
    for node in nodes:
        graph.add_node(pydot.Node(node[0], label=node[1], shape="box", style="rounded, filled", fillcolor="lightblue", fontsize="12", fontcolor="black"))
    for edge in edges:
        graph.add_edge(pydot.Edge(edge[0], edge[1], label=edge[2] if len(edge) > 2 else "", fontsize="10", fontcolor="blue", color="black"))
    return graph

# Conceptual Map 1: Ensuring Data Privacy and Security
nodes_privacy_security = [
    ("DC", "Data Collection"),
    ("IC", "Obtain Informed Consent"),
    ("AT", "Implement Anonymization Techniques"),
    ("DS", "Data Storage"),
    ("SDS", "Secure Data Storage Solutions"),
    ("LR", "Compliance with Legal Regulations"),
    ("DA", "Data Analysis"),
    ("EDU", "Ethical Data Usage Policies"),
    ("PA", "Regular Privacy Audits")
]

edges_privacy_security = [
    ("DC", "IC", ""),
    ("DC", "AT", ""),
    ("DS", "SDS", ""),
    ("DS", "LR", ""),
    ("DA", "EDU", ""),
    ("DA", "PA", "")
]

concept_map_privacy_security = create_concept_map("Ensuring Data Privacy and Security", nodes_privacy_security, edges_privacy_security)
concept_map_privacy_security.write_png('ensuring_data_privacy_and_security.png')

# Conceptual Map 2: Addressing Algorithmic Bias
nodes_algorithmic_bias = [
    ("DP", "Data Preparation"),
    ("DD", "Use Diverse and Representative Datasets"),
    ("PR", "Preprocessing to Remove Biases"),
    ("MT", "Model Training"),
    ("BA", "Bias Audits"),
    ("FE", "Fairness Evaluations"),
    ("MD", "Model Deployment"),
    ("TD", "Transparency in Model Decisions"),
    ("RM", "Regular Monitoring and Updates")
]

edges_algorithmic_bias = [
    ("DP", "DD", ""),
    ("DP", "PR", ""),
    ("MT", "BA", ""),
    ("MT", "FE", ""),
    ("MD", "TD", ""),
    ("MD", "RM", "")
]

concept_map_algorithmic_bias = create_concept_map("Addressing Algorithmic Bias", nodes_algorithmic_bias, edges_algorithmic_bias)
concept_map_algorithmic_bias.write_png('addressing_algorithmic_bias.png')

# Conceptual Map 3: Ensuring Transparency and Accountability
nodes_transparency_accountability = [
    ("RD", "Research Documentation"),
    ("DM", "Document Methodologies"),
    ("MC", "Detail Model Choices"),
    ("RI", "Result Interpretation"),
    ("EI", "Ensure Interpretability"),
    ("CL", "Communicate Limitations"),
    ("R", "Reproducibility"),
    ("PCA", "Provide Code and Data Access"),
    ("OSP", "Promote Open Science Practices")
]

edges_transparency_accountability = [
    ("RD", "DM", ""),
    ("RD", "MC", ""),
    ("RI", "EI", ""),
    ("RI", "CL", ""),
    ("R", "PCA", ""),
    ("R", "OSP", "")
]

concept_map_transparency_accountability = create_concept_map("Ensuring Transparency and Accountability", nodes_transparency_accountability, edges_transparency_accountability)
concept_map_transparency_accountability.write_png('ensuring_transparency_and_accountability.png')

# Conceptual Map 4: Ethical Use of AI
nodes_ethical_use_ai = [
    ("AID", "AI Development"),
    ("AEP", "Align with Ethical Principles"),
    ("PEV", "Prioritize Educational Values"),
    ("AII", "AI Implementation"),
    ("CHJ", "Complement Human Judgment"),
    ("EEO", "Enhance Educational Outcomes"),
    ("AIM", "AI Monitoring"),
    ("RER", "Regular Ethical Reviews"),
    ("SI", "Stakeholder Involvement")
]

edges_ethical_use_ai = [
    ("AID", "AEP", ""),
    ("AID", "PEV", ""),
    ("AII", "CHJ", ""),
    ("AII", "EEO", ""),
    ("AIM", "RER", ""),
    ("AIM", "SI", "")
]

concept_map_ethical_use_ai = create_concept_map("Ethical Use of AI", nodes_ethical_use_ai, edges_ethical_use_ai)
concept_map_ethical_use_ai.write_png('ethical_use_of_ai.png')

print("Conceptual maps for ethical considerations generated successfully.")
# Out:
# Conceptual maps for ethical considerations generated successfully.
